# %%
# %pip install konlpy
# Out:
# Requirement already satisfied: konlpy in c:\users\b8-01\appdata\local\programs\python\python313\lib\site-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in c:\users\b8-01\appdata\local\programs\python\python313\lib\site-packages (from konlpy) (1.5.2)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\b8-01\appdata\local\programs\python\python313\lib\site-packages (from konlpy) (5.3.0)
# Requirement already satisfied: numpy>=1.6 in c:\users\b8-01\appdata\local\programs\python\python313\lib\site-packages (from konlpy) (2.2.2)
# Requirement already satisfied: packaging in c:\users\b8-01\appdata\local\programs\python\python313\lib\site-packages (from JPype1>=0.7.0->konlpy) (24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade pip
# %pip install JPype1-0.5.7-cp27-none-win_amd64.whl
# Out:
# Requirement already satisfied: pip in c:\users\b8-01\appdata\local\programs\python\python313\lib\site-packages (25.0)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Requirement 'JPype1-0.5.7-cp27-none-win_amd64.whl' looks like a filename, but the file does not exist
# ERROR: JPype1-0.5.7-cp27-none-win_amd64.whl is not a supported wheel on this platform.

# %%
from konlpy.tag import Okt
import collections

okt = Okt()
text = '''
동해물과 백두산이 마르고 닳도록
하느님이 보우하사 우리나라 만세
무궁화 삼천리 화려 강산
대한 사람 대한으로 길이 보전하세
남산 위에 저 소나무 철갑을 두른 듯
바람 서리 불변함은 우리 기상일세
무궁화 삼천리 화려 강산
대한 사람 대한으로 길이 보전하세
가을 하늘 공활한데 높고 구름 없이
밝은 달은 우리 가슴 일편단심일세
무궁화 삼천리 화려 강산
대한 사람 대한으로 길이 보전하세
이 기상과 이 맘으로 충성을 다하여
괴로우나 즐거우나 나라 사랑하세
무궁화 삼천리 화려 강산
대한 사람 대한으로 길이 보전하세
'''
token = okt.pos(text)
clist = []
for word,tag in token:
    if tag in ['Noun','Adjective']:
        clist.append(word)
counts = collections.Counter(clist)
tag = counts.most_common(10)
print(tag)
# Out:
# [('대한', 8), ('무궁화', 4), ('삼천리', 4), ('화려', 4), ('강산', 4), ('사람', 4), ('길이', 4), ('보전', 4), ('우리', 2), ('기상', 2)]

# %%
# %pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\b8-01\appdata\local\programs\python\python313\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\b8-01\appdata\local\programs\python\python313\lib\site-packages (from wordcloud) (2.2.2)
# Requirement already satisfied: pillow in c:\users\b8-01\appdata\local\programs\python\python313\lib\site-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in c:\users\b8-01\appdata\local\programs\python\python313\lib\site-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\b8-01\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\b8-01\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\b8-01\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\b8-01\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\b8-01\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\b8-01\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\b8-01\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\b8-01\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
fpath = 'C:\Windows\Fonts\malgunbd.ttf'
wc = WordCloud(font_path=fpath, background_color='skyblue')
cloud = wc.generate_from_frequencies(dict(tag))

plt.figure(figsize=(10,8))
plt.imshow(cloud)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\W'
# <>:3: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\B8-01\AppData\Local\Temp\ipykernel_6828\821376032.py:3: SyntaxWarning: invalid escape sequence '\W'
#   fpath = 'C:\Windows\Fonts\malgunbd.ttf'
