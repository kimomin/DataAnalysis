# %%
import pandas as pd
import matplotlib.pyplot as plt  # 차트 사용 기본
plt.rc('font', family='Malgun Gothic')
data = {'이름':['홍길동','강감찬','이순신','최영'],
        '점수': [50, 60, 80, 65]}

df = pd.DataFrame(data)

# 판다스의 plot 이용한 차트 작성
# 데이터프레임.plot()

df.plot(kind='bar', x='이름', rot=0, ylim=[0,100], color='y')

for i in list(df.index):
    rate = (df.loc[i]['점수']/df['점수'].sum())*100
    plt.text(x=i-0.1, y=df.loc[i]['점수']+0.3, s=str(df.loc[i]['점수'])+'점')
    plt.text(x=i-0.15, y=df.loc[i]['점수']/2, s=f'{rate:.1f}%')
# plt.text(x=1, y=60, s='값')
meanval = df['점수'].mean()
plt.axhline(y=meanval, color='r', linestyle='dashed')
plt.text(x=0,y=meanval+1, s=f'평균: {meanval:.2f}')

plt.xlabel('학생 이름')
plt.ylabel('점수')
plt.title('학생별 시험 점수')

plt.savefig('graph01.png', dpi=400) 
print('파일이 저장되었습니다')
plt.show()
# Out:
# 파일이 저장되었습니다

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# subplot 작성, matplotlib 이용
data = {'year' : [2010,2011,2012,2013,2014],
        'sales' : [500,800,1200,900,1500],
        'expenses' : [300,400,600,500,800]
        }
df2 = pd.DataFrame(data)

# subplot 생성
fig, axes = plt.subplots(2,2,figsize=(10,9))

# 선 그래프
axes[0,0].plot(df2['year'], df2['sales'])
axes[0,0].set_title('Sales', fontsize=12)
axes[0,0].set_xlabel('year', fontsize=9)
axes[0,0].set_xticks(df2['year'])

# 막대 그래프
axes[0,1].bar(df2['year'], df2['expenses'])
axes[0,1].set_title('Expenses')

# 산점도 그래프
axes[1,0].scatter(df2['sales'], df2['expenses'])
axes[1,0].set_title('Sales - Expenses')

# 히스토그램 그래프
axes[1,1].hist(df2['sales'],bins=4)
axes[1,1].set_title('Sales Distribution')

# 그래프 간 간격 자동 조절
plt.tight_layout()

plt.show()

# %%
# %pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\users\b8-01\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\b8-01\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\b8-01\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\b8-01\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\b8-01\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\b8-01\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\b8-01\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\b8-01\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\b8-01\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\b8-01\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\b8-01\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\b8-01\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\b8-01\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\b8-01\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\b8-01\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# subplot 작성, seaborn 차트 작성
data = {'year' : [2010,2011,2012,2013,2014],
        'sales' : [500,800,1200,900,1500],
        'expenses' : [300,400,600,500,800]
        }
df2 = pd.DataFrame(data)

# subplot 생성
fig, axes = plt.subplots(2,2,figsize=(10,9))

# 선 그래프
sns.lineplot(data=df2, x='year', y='sales', ax=axes[0,0])
axes[0,0].set_title('Sales', fontsize=12)
axes[0,0].set_xlabel('year', fontsize=9)

# 막대 그래프
sns.barplot(data=df2, x='year', y='expenses', ax=axes[0,1], palette='Set1')

# 산점도 그래프
sns.scatterplot(data=df2, x='sales', y='expenses', ax=axes[1,0])

# 히스토그램 그래프
sns.histplot(data=df2, x='sales', ax=axes[1,1])

plt.show()
# Out:
# C:\Users\B8-01\AppData\Local\Temp\ipykernel_3708\260483220.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df2, x='year', y='expenses', ax=axes[0,1], palette='Set1')
