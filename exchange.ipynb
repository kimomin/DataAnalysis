# %% [markdown]
# # 네이버 금융 환율 정보

# %%
# %pip install html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

url = 'https://finance.naver.com/marketindex/exchangeList.naver'
dfs = pd.read_html(url, encoding='cp949', header=1)
# Out:
# /opt/anaconda3/envs/data_analysis/lib/python3.13/site-packages/bs4/__init__.py:228: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")

# %%
dfs
# Out:
# [              통화명    매매기준율     사실 때     파실 때    보내실 때    받으실 때  미화환산율
#  0          미국 USD  1458.30  1483.82  1432.78  1472.50  1444.10  1.000
#  1        유럽연합 EUR  1511.31  1541.38  1481.24  1526.42  1496.20  1.036
#  2   일본 JPY (100엔)   939.60   956.04   923.16   948.80   930.40  0.644
#  3          중국 CNY   199.18   209.13   189.23   201.17   197.19  0.137
#  4          홍콩 HKD   187.13   190.81   183.45   189.00   185.26  0.128
#  5          대만 TWD    44.22    50.01    39.80      NaN      NaN  0.030
#  6          영국 GBP  1807.27  1842.87  1771.67  1825.34  1789.20  1.239
#  7          오만 OMR  3792.72  4058.21  3527.23      NaN      NaN  2.601
#  8         캐나다 CAD  1003.85  1023.62   984.08  1013.88   993.82  0.688
#  9         스위스 CHF  1600.68  1632.21  1569.15  1616.68  1584.68  1.098
#  10        스웨덴 SEK   131.42   135.75   123.93   132.73   130.11  0.090
#  11         호주 AUD   905.90   923.74   888.06   914.95   896.85  0.621
# ...

# %%
urlUSD = 'https://finance.naver.com/marketindex/exchangeDailyQuote.naver?marketindexCd=FX_USDKRW&page='
urlEUR = 'https://finance.naver.com/marketindex/exchangeDailyQuote.naver?marketindexCd=FX_EURKRW&page=1'

df = pd.DataFrame()
for page_num in range(1,5):
    url = f'{url}{page_num}'
    dfs = pd.read_html(urlUSD, encoding='cp949', header=1)
    df = pd.concat([df,dfs[0]])
df
# Out:
# /opt/anaconda3/envs/data_analysis/lib/python3.13/site-packages/bs4/__init__.py:228: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")
# /opt/anaconda3/envs/data_analysis/lib/python3.13/site-packages/bs4/__init__.py:228: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")
# /opt/anaconda3/envs/data_analysis/lib/python3.13/site-packages/bs4/__init__.py:228: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
# ...
